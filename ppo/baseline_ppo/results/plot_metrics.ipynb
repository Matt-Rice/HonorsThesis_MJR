# %% [markdown]
# # Printing Metrics

# %%
import pandas as pd
import matplotlib.pyplot as plt
wall = pd.read_csv('./el.csv')
# maze = pd.read_csv('../logs/maze.csv')
# passage = pd.read_csv('../logs/passage.csv')
# space = pd.read_csv('../logs/space.csv')
# Display the cleaned DataFrame
wall.head()
# Out:
#       Wall time  Step       Value
# 0  1.741492e+09  1024  321.333344
# 1  1.741492e+09  1536  191.000000
# 2  1.741492e+09  2048  143.214279
# 3  1.741492e+09  2560  106.125000
# 4  1.741492e+09  3072   85.000000

# %%
def plot_metrics(df):
    
    # df.columns = ['episode', 'loss', 'reward', 'steps', 'duration']

    # # Remove unnecessary words/characters and convert to numeric types
    # df['episode'] = df['episode'].str.extract(r'(\d+)').astype(int)  # Extract numeric part of "Episode X"
    # df['loss'] = df['loss'].str.replace('Loss: ', '').astype(float)  # Remove "Loss: " and convert to float
    # df['reward'] = df['reward'].str.replace('Reward: ', '').astype(float)  # Remove "Reward: " and convert to float
    # df['steps'] = df['steps'].str.replace('Steps: ', '').astype(int)  # Remove "Steps: " and convert to int
    # df['duration'] = df['duration'].str.replace('Duration: ', '').astype(float)  # Remove "Duration: " and convert to float

    # # Plot Rewards over Episodes
    # plt.figure(figsize=(12, 6))
    # plt.plot(df['episode'], df['reward'], label="Reward", color="blue", alpha=0.7)
    # plt.xlabel("Episodes")
    # plt.ylabel("Reward")
    # plt.title("Reward Trend Over Time")
    # plt.legend()
    # plt.grid()
    # plt.show()
    
    # # Plot Losses over Episodes
    # plt.figure(figsize=(12, 6))
    # plt.plot(df['episode'], df['loss'], label="Loss", color="red", alpha=0.7)
    # plt.xlabel("Episodes")
    # plt.ylabel("Loss")
    # plt.title("Loss Trend Over Time")
    # plt.legend()
    # plt.grid()
    # plt.show()

    # Plot Steps over Episodes
    plt.figure(figsize=(10, 6))
    plt.plot(df['Step'], df['Value'], label="Steps", color="green", alpha=0.7)
    plt.xlabel("Total Steps")
    plt.ylabel("Steps per episode")
    plt.title("Steps Per Episode Trend Over Total Steps")
    plt.legend()
    plt.grid()
    plt.show()

# %%
plot_metrics(wall)
# plot_metrics(maze)
# plot_metrics(passage)
# plot_metrics(space)

# %%
df = pd.read_csv('../logs/training_log.txt')
plot_metrics(df)
